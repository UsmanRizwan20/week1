# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/UsmanRizwan20/week1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Lane 4: CTR / Engagement Opportunity Scoring
#
# I chose this lane because improving CTR can increase traffic without creating new content. The dataset contains impressions, clicks, CTR, average position, engagement metrics, and freshness indicators that can help identify pages that may be underperforming relative to their visibility.
#
# The goal is not simply to train a model. The goal is to help content teams decide which pages deserve review first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Research Question
#
# Which visible pages under-capture clicks and should be reviewed for metadata, content, or engagement improvements?
#
# Unit of Analysis
#
# A single content page.
#
# Output
#
# A ranked list of pages that appear to have CTR improvement opportunities.
#
# Decision
#
# Which pages should be reviewed first by the SEO or content team.
#
# Action
#
# Review titles, meta descriptions, search intent alignment, and engagement elements on the page.
#
# Cost of a Wrong Recommendation
#
# If a page is incorrectly flagged, time may be spent reviewing a page that does not need improvement.
#
# If a genuinely underperforming page is missed, potential traffic and engagement gains may be lost.
#
# Why ML Can Help
#
# Manually reviewing thousands of pages is difficult. ML can help prioritize pages by identifying patterns associated with lower CTR and engagement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
import os

csv_file = None

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            csv_file = os.path.join(root, file)
            print("Found:", csv_file)
            break
    if csv_file:
        break

df = pd.read_csv(csv_file)

print("Rows:", len(df))
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Found: ./sample_data/california_housing_test.csv
# Rows: 3000
#
# Columns:
# ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This project identifies patterns and opportunities within the available data.
#
# The analysis is observational and does not prove causation. A page with low CTR may be affected by multiple factors, and a recommendation does not guarantee performance improvement.
#
# Any suggested actions should be validated through further review or testing.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
